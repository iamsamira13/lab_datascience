# %%
marks = [78, 85, 92, 67, 88, 73, 88, 73]
sorted_marks = sorted(marks, reverse=True)

print("Sorted marks in descending order:", sorted_marks)
# Out:
# Sorted marks in descending order: [92, 88, 88, 85, 78, 73, 73, 67]

# %%
marks = [85, 92, 78, 90, 88, 76, 95]
marks.sort(reverse=True)

print("Student marks sorted in descending order:")
print(marks)
# Out:
# Student marks sorted in descending order:
# [95, 92, 90, 88, 85, 78, 76]

# %%
"""2. Use a list comprehension to create a new list containing only the even numbers between 1 and 20,
demonstrating a more concise and readable alternative to traditional loops."""


even_numbers = [x for x in range(1, 21) if x % 2 == 0]


print("Even numbers between 1 and 20:", even_numbers)

# %%
"""Question 3"""

def num_gen():
    for i in range(1, 6):
        yield i  

gen = num_gen()

for num in gen:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
"""Question 4"""
import random

students = ["Ram", "Shyam", "Mohan", "Sita", "Gita", "Rita"]
print(f"The list of students: {students}")

volunteers = random.sample(students, 3) #creates a list of unique elements chosen from the population sequence.
#If k is greater than the total number of students in the list, the function will raise a ValueError

print("Total:", volunteers)
# Out:
# The list of students: ['Ram', 'Shyam', 'Mohan', 'Sita', 'Gita', 'Rita']
# Total: ['Ram', 'Sita', 'Mohan']
